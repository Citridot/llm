# %%
# !pip install transformers datasets
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 99.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 486.2/486.2 kB 38.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 29.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 97.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 88.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 15.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.5/212.5 kB 29.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.3/134.3 kB 19.6 MB/s eta 0:00:00
# ...

# %%
# !pip install torch einops
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 5.5 MB/s eta 0:00:00
# ...

# %%
import transformers
import torch
from transformers import pipeline, AutoTokenizer

# %%
#model = transformers.AutoModelForCausalLM.from_pretrained(
#  'mosaicml/mpt-30b-chat',
#  trust_remote_code=True
#)

model = transformers.AutoModelForCausalLM.from_pretrained(
  'lmsys/vicuna-7b-v1.3',
  trust_remote_code=True
)

#config = transformers.AutoConfig.from_pretrained('mosaicml/mpt-7b', trust_remote_code=True)
#config.attn_config['attn_impl'] = 'triton'
#config.init_device = 'cuda:0' # For fast initialization directly on GPU!

#model = transformers.AutoModelForCausalLM.from_pretrained(
#  'mosaicml/mpt-7b',
#  config=config,
#  torch_dtype=torch.bfloat16, # Load model weights in bfloat16
#  trust_remote_code=True
#)
# Out:
# ...
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# ...

# %%
#tokenizer = AutoTokenizer.from_pretrained('EleutherAI/gpt-neox-20b')
tokenizer = AutoTokenizer.from_pretrained('fxmarty/tiny-llama-fast-tokenizer')

# %%
generator = pipeline('text-generation', model=model, tokenizer=tokenizer)
#generator = pipeline('text-generation', model=model)
# Out:
# Xformers is not installed correctly. If you want to use memory_efficient_attention to accelerate training use the following command to install Xformers
# pip install xformers.

# %%
#with torch.autocast('cuda', dtype=torch.bfloat16):
#generator("Tell me about Earth.", max_new_tokens=100, do_sample=True, use_cache=True)
generator("Tell me about Earth.", max_new_tokens=100)
# Out:
# [{'generated_text': 'Tell me about Earth.\n\nThe Earth is a planet in the solar system. It is the third planet from the sun and is the largest of the terrestrial planets. The Earth is a rocky planet with a thin atmosphere and a magnetic field that protects it from the harmful effects of solar radiation. The Earth has a single moon, which is called the Moon. The Earth is also home to a wide variety of life forms, including humans.\n\nThe Earth is a unique planet in the solar system'}]
